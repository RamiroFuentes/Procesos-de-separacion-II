# %%
# %run function_zoo.py

# %%
Z_p=[.2,.25,.25,.3]
K_p=[3.4,1.5,.7,.35]

[psi,f_psi] = Rachford_Rice_4(Z_p,K_p,0,1,.1)

plt.figure(figsize=(10,5))
plt.title("Gráfica en el intervalo de 0 a 1")
plt.plot(psi,f_psi,marker='.')
plt.grid()
plt.xlabel('$\psi$')
plt.ylabel('$f(\psi$)').set_rotation(0)
plt.axvline(x=1,color='r',ls='dotted')
plt.axvline(x=0,color='r',ls='dotted')
plt.show()

print("""
En la siguiente figura se muestra un error causado por división entre cero, esto quiere decir que existe una 
indeterminación en algún punto de nuestra funcion, lo cual demuestra que las funciones no siempre son continuas
fuera de nuestro domino de 0 a 1.""")

plt.figure(figsize=(10,5))
[psi,f_psi] = Rachford_Rice_4(Z_p,K_p,-10,10,1)

plt.plot(psi,f_psi,marker='.')
plt.grid()
plt.xlabel('$\psi$')
plt.ylabel('$f(\psi$)').set_rotation(0)
plt.title("Gráfica en el intervalo de -10 a 10")
plt.axvline(x=1,color='r',ls='dotted')
plt.axvline(x=0,color='r',ls='dotted')
plt.show()
# Out:
# En la siguiente figura se muestra un error causado por división entre cero, esto quiere decir que existe una
# indeterminación en algún punto de nuestra funcion, lo cual demuestra que las funciones no siempre son continuas
# fuera de nuestro domino de 0 a 1.
